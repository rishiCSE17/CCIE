# %% [markdown]
# ## Basic Operation
# You have an empty sequence, and you will be given N queries. Each query is one of these three types:
#
# 1 x  -Push the element x into the stack. <br>
# 2    -Delete the element present at the top of the stack. <br>
# 3    -Print the maximum element in the stack. <br>
#
# + https://www.hackerrank.com/challenges/maximum-element/problem

# %%
# inefficient one 
stack = []
for i in range(int(input())):
    cmd = input().split(' ')
    
    if cmd[0] == '1':
        stack.insert(0,int( cmd[1] ))

    elif cmd[0] == '2':
        stack.pop(0)
    
    elif cmd[0] == '3':
        print(max(stack))

# %%
# efficient one

stack = []
max_val= None
for i in range(int(input())):
    cmd = input().split(' ')
    
    if cmd[0] == '1':
        val = int( cmd[1] )
        if max_val == None:
            max_val = val
        elif val > max_val:
            max_val = val
        stack.insert(0,val)

    elif cmd[0] == '2':
        stack.pop(0)
        if len(stack) != 0:
            max_val = max(stack)
        else:
            max_val = None
    
    elif cmd[0] == '3':
        print(max_val)

# %%
stack = []
def isBalanced(s):
    global stack
    
    if len(s)%2 != 0:
        return 'NO'
 
    for c in s:
        if c == '(' or c == '{' or c == '[':
            stack.insert(0,c)

        elif c == ')':
            if stack[0] == '(':
                stack.pop(0)
            else:
                return 'NO'
        elif c == '}':
            if stack[0] == '{':
                stack.pop(0)
            else:
                return 'NO'
        elif c == ']':
            if stack[0] == '[':
                stack.pop(0)
            else:
                return 'NO'

    if len(stack) == 0:
        return 'YES'
    else:
        return 'NO'

# %% [markdown]
# ## Balanced Brackets
#
# A bracket is considered to be any one of the following characters: (, ), {, }, [, or ].
#
# Two brackets are considered to be a matched pair if the an opening bracket (i.e., (, [, or {) occurs to the left of a closing bracket (i.e., ), ], or }) of the exact same type. There are three types of matched pairs of brackets: [], {}, and ().
#
# A matching pair of brackets is not balanced if the set of brackets it encloses are not matched. For example, {[(])} is not balanced because the contents in between { and } are not balanced. The pair of square brackets encloses a single, unbalanced opening bracket, (, and the pair of parentheses encloses a single, unbalanced closing square bracket, ].
#
# By this logic, we say a sequence of brackets is balanced if the following conditions are met:
# * It contains no unmatched brackets.
# * The subset of brackets enclosed within the confines of a matched pair of brackets is also a matched pair of brackets.
#
# Given $n$ strings of brackets, determine whether each sequence of brackets is balanced. If a string is balanced, return YES. Otherwise, return NO.
#
# * https://www.hackerrank.com/challenges/balanced-brackets/problem

# %%
def isBalanced(s):
    #odd len is imbalanced 
    if len(s)%2 != 0:
        return 'NO'

    stack = []
    for i in range(len(s)):

        #blind push for opening brackets
        if s[i] in ['(' , '{' , '[' ]:
            stack.insert(0,s[i])

        #sanity check as 'stack[0]' cant be checked for empty stack
        elif i != len(s)-1 and len(stack)==0:
            return 'NO'

        #pops
        elif s[i] == ')':
            if stack[0] == '(':
                stack.pop(0)
            else:
                return 'NO'
        elif s[i] == '}':
            if stack[0] == '{':
                stack.pop(0)
            else:
                return 'NO'
        elif s[i] == ']':
            if stack[0] == '[':
                stack.pop(0)
            else:
                return 'NO'
            
    #balance if stack is empty
    if len(stack) == 0 :
        return 'YES'
    else:
        return 'NO'

# %% [markdown]
# ## Equal Stacks
#
# You have three stacks of cylinders where each cylinder has the same diameter, but they may vary in height. You can change the height of a stack by removing and discarding its topmost cylinder any number of times.
#
# Find the maximum possible height of the stacks such that all of the stacks are exactly the same height. This means you must remove zero or more cylinders from the top of zero or more of the three stacks until they're all the same height, then print the height. The removals must be performed in such a way as to maximize the height.
#
# Note: An empty stack is still a stack.
# * https://www.hackerrank.com/challenges/equal-stacks/problem

# %%
def cumsum(a):
    s=0
    l=[]
    for i in range(len(a)):
        #reading the array reverse and cumsum 
        s += a[len(a)-i-1] 
        l.append(s)
    return set(l)

def equalStacks(h1, h2, h3):
    if len(h1)==0 or len(h2)==0 or len(h3)==0:
        return 0
    
    #max common value
    return max(
        list(
            cumsum(h1).intersection(
                cumsum(h2).intersection(cumsum(h3))
            )
        )
    )

# %%
set.intersection()

# %% [markdown]
# # Welcome
# hello everybody goo afternoon, my name is Saptarshi and on behalf of my team with Prof tasos, ionis and andrew
# I welcome you to the presentation on projecy victory.
# we're a research group from div of CS LSBU
#
# # 5g-sec-cloud
# our product primarily caters to the services that combines sec cloud and 5g landscapes , and its based on somethig called Edge-cloud technology
#
# # Edge cloud
# so, what is edge cloud in the fidt place?
# well, by def it pushes the cloud resources close to the edge, where end users are directly connected
#
# the benifit of placing cloud services in a close proximity to its users reduces the latecy of accessing them
#
# e.g. youtube places most watched videos for a given region locally to its regional servers,
# thus while streaming them, despite of limited internet bandwidth, better QoE can be served
#
# no wonder several standards have been surfaced so far to utilise this technology,
#
# microsoft's cloudlet and cisco's fog
#
# some other open standards such as ETSI, openEdge, Openfog etc. are also there
#
#
# # today tomorrow
#
# Moreover the market is growing, mcensy's 2020 report 90% enterprise data are now hosted in cloud and a 25% growth is also projected in coming 5 years
#
# # value chain
# the infra is layered in three groups,
# * top : edge application
# * bottom : devices that use those apps
# * middle : the fabric to connect them
# * e.g. siri
#
# connectivity layer serves several service, one of which is the orchestration, where our project is targetted on
#
# # status-qup
# Lets have a look how the state of the art of the orchestration looks like
# * at the bottom of the stack we have end users euipments that consume services from the edge infra
# * which is a cluster of virtualised physical servers
# * the vertualization provides platform and localtion agnostic features
# * services are hosted on top as micro-services
# * and their deployment is governed by Management and orchestration layer that sits on top
# * the primary job of MANO is to manage placement of services and monito resource consumption
#
# * if there's a inconsistancy of load, services are relocated which is also called service migration
#
# ## reliability
#
# 	that brings me 1st limitation
#
# 	currenly all orchestrators deploy and relocates services based on demands and present state of utilization
# 	which lacs the inclusion of reliability based on historical behaviur
#
# 	we propose to extend the MANO A deep learning framework that analyses the historical reliability of servers
# 	to assist the service transfer to make it more reliable
#
# ## Security
# 	the second limitaion takes place during the transfer process
# 	* when a serive is on the fly, its not protected by the security policies emposed by micro-service layer
# 	* hence a malicius code injection may take place
# 	* which may compromise the whole infra
# 	* this happens because the authentication mechanism is centralised
#
# ### Our solution
# 	Our take to counter this issue, by making the authentication distributed,
# 	thus we integrate a blockchain framework
# 	* despite of distributed its immutable, i.e. once you make an entry, it cant be altered
# 	* Victory uses this property to fix the vulnaribility
#
# 	before the transfer takes place, the origin server makes an entry about the service to the BC
# 	if a malware injection takes place, the attributes would change
# 	upon receing the potential receiver makes a sanity check
# 	if the incomming service is identical to what was sent
#
# 	in this case since the service is altered, the check would fail,
# 	thus the receiver would reject the service and that would soil in intension of the malicious user
#
# # Existing products
# Now, regarding the existing products
# * bla bla bla
#
# * and they face is said issues
# * which victory is going to address, especially :
# * A more reliabile transfer and better protection from man in the middle atatck
#
# # USPs
#
# speak as written
#
#
# # Trends
# ## Trend1
# Regarsing the market volume,
# 	MCensy 2020 repots states some of the use cases cloud native and edge computing is massively used
# 	e.g. heathcare, transport and logistics, aggriculture adn media
# 	the merket is expected to become $215B in next 5 years
#
# ## Trend2
#
# thrend in secury market
# 	research future suggets it to grow upto $200B by 2025
# 	where 5G security alone grabs a share of 4B by 2023, projected by mind commers
#
# # Our survey
# To complement this we undergo our own active market survey
# 	among many results we accumulated,
# 	responses flags cloud native and security being the most imp challage
# 	and in secuty MITM and DDos are the most lithal atatcks to be tackled
#
# # market segment
# We are primairily trget the orcestration market among the various other domains that contributed to the technology
# 	ovum's  orecasts suggests this to grow worth $11B by next 2 years
#
# # business model
#
# regardig the business model,
# 	although Telcom and IT industris are active stakeholders,
# 	however we're targetting the SME through a B2B manner
# 	customers would be IoT and edge coud providor
#
# 	the reviniew plan can be
# 	1. a flat rate
# 	2. based on number of deploymetns
#      or 3. through a portion of GPL
#
# # IP
#
# We've already patented out 5g testbed platform for experiments
# and on the process of pettenting the proposed product .
#
# # Roadmap
# our plan to initiate as spin-off company, aiming to break-even in 3-4 years
# team member
# 	tasos being the most experienced member in the tram
# 	myself, specialised in softwarization
# 	ionis has experties in cyber sec
# 	and andrew works on the innovation and business dev
#
# # Proof of concept
# finally,
# 	regarsing the PoC
# 	we'd be using our properiatary testbed for demonstration
# 	extending the feature by bockchain integration and
# 	demonstrate the capabilities by emulating MITM over a live migration
